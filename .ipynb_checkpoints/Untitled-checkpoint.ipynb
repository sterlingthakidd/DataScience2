# %%
import pandas as pd 
import seaborn as sns 
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(data=df, x="bmi", y='charges')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
smokers = df[df.smoker =="yes"]
nonsmokers = df[df.smoker =="no"]

# %%
smokers.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.059674  0.081183  0.368224
# bmi       0.059674  1.000000 -0.012619  0.806481
# children  0.081183 -0.012619  1.000000  0.035945
# charges   0.368224  0.806481  0.035945  1.000000

# %%
nonsmokers.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.122638  0.033395  0.627947
# bmi       0.122638  1.000000  0.019208  0.084037
# children  0.033395  0.019208  1.000000  0.138929
# charges   0.627947  0.084037  0.138929  1.000000

# %%
def trainModel(trainDF, x):
    for i in range(len(trainDF)):
        slope = (trainDf.iloc[i]['charges'] - y ) /  (trainDF.iloc[i]['bmi'] - x)
        slopes.append(slope)
         #(y2-y1)/(x2 -x1)
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(smokers, 0, b) 
print("y = " + str(m) + "x + " + str(b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11792\698346714.py in <module>
#       6     return sum(slopes)/len(slopes)
#       7 b = 10000
# ----> 8 m = trainModel(smokers, 0, b)
#       9 print("y = " + str(m) + "x + " + str(b))
#
# TypeError: trainModel() takes 2 positional arguments but 3 were given

# %%
def testModel(testDF, m, b):
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["bmi"] + b)
        actual = (testDF.iloc[i]["charges"])
        differnce = abs(predicted - actual)
        if difference <= 1000:
            checks.append(1)
        else:
            checks.append(0)
        return
# Out:
#   File "C:\Users\shatchiv\AppData\Local\Temp\ipykernel_11792\3824386543.py", line 2
#
#     ^
# IndentationError: expected an indented block
